# %% [markdown]
# <a href="https://colab.research.google.com/github/shannonshih/Tibame_GAD245-Practice-HW_0120/blob/main/03_04_Pandas_%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pandas openpyxl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('/content/drive/MyDrive/AI人才應用/20250109T010859Z-001/2024-12 AI數據應用人才養成班/data/R公司_人員資料.xlsx',engine='openpyxl')
data.head()
# Out:
#    員工編號(EmployeeNumber) 性別(Gender)  年齡(Age) 是否為成年人(Over18)  \
# 0                     1     Female       41              Y
# 1                     2       Male       49              Y
# 2                     4       Male       37              Y
# 3                     5     Female       33              Y
# 4                     7       Male       27              Y
#
#   婚姻狀態(MaritalStatus)  通勤距離(DistanceFromHome)  教育程度(Education)  \
# 0              Single                       1                2
# 1             Married                       8                1
# 2              Single                       2                2
# 3             Married                       3                4
# 4             Married                       2                1
#
#   教育專業領域(EducationField)          部門(Department)          職位名稱(JobRole)  ...  \
# 0          Life Sciences                   Sales        Sales Executive  ...
# ...

# %%
import pandas as pd

# Read the Excel file
data = pd.read_excel('/content/drive/MyDrive/AI人才應用/20250109T010859Z-001/2024-12 AI數據應用人才養成班/data/R公司_人員資料.xlsx', engine='openpyxl')

# List all column names
print(data.columns)
# Out:
# Index(['員工編號(EmployeeNumber)', '性別(Gender)', '年齡(Age)', '是否為成年人(Over18)',
#        '婚姻狀態(MaritalStatus)', '通勤距離(DistanceFromHome)', '教育程度(Education)',
#        '教育專業領域(EducationField)', '部門(Department)', '職位名稱(JobRole)',
#        '職位等級(JobLevel)', '在該公司工作總年資(YearsAtCompany)',
#        '在該職位工作年資(YearsInCurrentRole)', '在該職等工作年資(YearsSinceLastPromotion)',
#        '與現任管理者工作年資(YearsWithCurrManager)', '總工作年資(TotalWorkingYears)',
#        '過去工作公司家數(NumCompaniesWorked)', '每日工資額(DailyRate)',
#        '每小時工資額(HourlyRate)', '月收入(MonthlyIncome)', '月費率(MonthlyRate)',
#        '標準工作時間(StandardHours)', '加班(OverTime)', '調薪百分比(PercentSalaryHike)',
#        '股票選擇權等級(StockOptionLevel)', '績效評估(PerformanceRating)',
#        '出差頻率(BusinessTravel)', '去年訓練時間(TrainingTimesLastYear)',
#        '工作滿意度(JobSatisfaction)', '工作環境滿意度(EnvironmentSatisfaction)',
#        '工作投入(JobInvolvement)', '工作生活平衡(WorkLifeBalance)',
#        '人際關係滿意度(RelationshipSatisfaction)', '離職(Attrition)'],
#       dtype='object')

# %%
# 請列出 離職 這個欄位的資料

# Extract the '離職' column
resign = data['離職(Attrition)']
resign
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: 離職(Attrition), Length: 1470, dtype: object

# %%
# 請查詢並列出 已經離職 的員工

resign_employee = data['離職(Attrition)'] == 'Yes'
# data[resign_employee]['員工編號(EmployeeNumber)']
pd.DataFrame(data[resign_employee])
# Out:
#       員工編號(EmployeeNumber) 性別(Gender)  年齡(Age) 是否為成年人(Over18)  \
# 0                        1     Female       41              Y
# 2                        4       Male       37              Y
# 14                      19       Male       28              Y
# 21                      27       Male       36              Y
# 24                      31       Male       34              Y
# ...                    ...        ...      ...            ...
# 1438                  2023       Male       23              Y
# 1442                  2027       Male       29              Y
# 1444                  2032       Male       56              Y
# 1452                  2044       Male       50              Y
# 1461                  2055       Male       50              Y
#
#      婚姻狀態(MaritalStatus)  通勤距離(DistanceFromHome)  教育程度(Education)  \
# 0                 Single                       1                2
# 2                 Single                       2                2
# ...

# %%
# 請增加一個新的欄位 離職_數值
# 並分別用 0 跟 1 來表示這個員工是否離職

# resign_employee = data['離職(Attrition)'] == 'Yes'
# data['離職(Attrition)'] == 'Yes'
# resign_value1 = 1

# resign_value2 = 0
# data['離職(Attrition)'] == 'Yes':
resign_employee.index == True
resign_value = 1
data[resign_employee][resign_value]
# resign_value = data[data.離職(Attrition)] == 'Yes'
# resign_value = 0
# data['離職_數值'] = data['離職(Attrition)'].apply(resign_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-456401c84682> in <cell line: 0>()
#       8 # resign_value2 = 0
#       9 # data['離職(Attrition)'] == 'Yes':
# ---> 10 if resign_employee.index == True:
#      11     resign_value = 1
#      12 data[resign_employee][resign_value]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
